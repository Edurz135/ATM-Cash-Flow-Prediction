# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("AggregatedData.csv")

# %%
data
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1/1/2011                 50
# 1          Mount Road ATM         1/1/2011                253
# 2             Airport ATM         1/1/2011                 98
# 3            KK Nagar ATM         1/1/2011                265
# 4      Christ College ATM         1/1/2011                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# 4                              25                            49
# ...                           ...                           ...
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                      123800                      41700
# 1                      767900                     270900
# 2                      503400                     347700
# 3                      945300                     532600
# 4                      287700                     148200
# ...                       ...                        ...
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                            82100  Saturday                 H           H
# 1                           497000  Saturday                 C           H
# 2                           155700  Saturday                 C           H
# 3                           412700  Saturday                 C           H
# 4                           139500  Saturday                 C           H
# ...                            ...       ...               ...         ...
# 11584                       322600    FRIDAY                 H           H
# 11585                       132600    FRIDAY                 H           H
# 11586                       133100    FRIDAY                 H           H
# 11587                       128800    FRIDAY                 H           H
# 11588                       336200    FRIDAY                 H           H
#
#       Holiday Sequence
# 0                  WHH
# 1                  WHH
# 2                  WHH
# 3                  WHH
# 4                  WHH
# ...                ...
# 11584              WHH
# 11585              WHH
# 11586              WHH
# 11587              WHH
# 11588              WHH
#
# [11589 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11589 entries, 0 to 11588
# Data columns (total 12 columns):
# ATM Name                        11589 non-null object
# Transaction Date                11589 non-null object
# No Of Withdrawals               11589 non-null int64
# No Of XYZ Card Withdrawals      11589 non-null int64
# No Of Other Card Withdrawals    11589 non-null int64
# Total amount Withdrawn          11589 non-null int64
# Amount withdrawn XYZ Card       11589 non-null int64
# Amount withdrawn Other Card     11589 non-null int64
# Weekday                         11589 non-null object
# Festival Religion               11589 non-null object
# Working Day                     11589 non-null object
# Holiday Sequence                11589 non-null object
# dtypes: int64(6), object(6)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        No Of Withdrawals  No Of XYZ Card Withdrawals  \
# count       11589.000000                11589.000000
# mean          123.341099                   67.567694
# std            67.315288                   47.849517
# min             1.000000                    0.000000
# 25%            79.000000                   34.000000
# 50%           115.000000                   57.000000
# 75%           158.000000                   87.000000
# max           491.000000                  345.000000
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# count                  11589.000000            1.158900e+04
# mean                      55.773406            5.223059e+05
# std                       38.506475            3.248167e+05
# min                        0.000000            1.000000e+02
# 25%                       25.000000            3.057000e+05
# 50%                       50.000000            4.700000e+05
# 75%                       78.000000            6.716000e+05
# max                      310.000000            2.549800e+06
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card
# count               1.158900e+04                 1.158900e+04
# mean                3.345604e+05                 1.877455e+05
# std                 2.470771e+05                 1.502351e+05
# min                 0.000000e+00                 0.000000e+00
# 25%                 1.560000e+05                 7.910000e+04
# 50%                 2.816000e+05                 1.586000e+05
# 75%                 4.485000e+05                 2.560000e+05
# max                 1.907800e+06                 1.472600e+06

# %%
data['Weekday'] = data['Weekday'].str.upper()
data
#Converted all entries of Weekday column to uppercase since there was an anomaly in format
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1/1/2011                 50
# 1          Mount Road ATM         1/1/2011                253
# 2             Airport ATM         1/1/2011                 98
# 3            KK Nagar ATM         1/1/2011                265
# 4      Christ College ATM         1/1/2011                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# 4                              25                            49
# ...                           ...                           ...
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                      123800                      41700
# 1                      767900                     270900
# 2                      503400                     347700
# 3                      945300                     532600
# 4                      287700                     148200
# ...                       ...                        ...
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                            82100  SATURDAY                 H           H
# 1                           497000  SATURDAY                 C           H
# 2                           155700  SATURDAY                 C           H
# 3                           412700  SATURDAY                 C           H
# 4                           139500  SATURDAY                 C           H
# ...                            ...       ...               ...         ...
# 11584                       322600    FRIDAY                 H           H
# 11585                       132600    FRIDAY                 H           H
# 11586                       133100    FRIDAY                 H           H
# 11587                       128800    FRIDAY                 H           H
# 11588                       336200    FRIDAY                 H           H
#
#       Holiday Sequence
# 0                  WHH
# 1                  WHH
# 2                  WHH
# 3                  WHH
# 4                  WHH
# ...                ...
# 11584              WHH
# 11585              WHH
# 11586              WHH
# 11587              WHH
# 11588              WHH
#
# [11589 rows x 12 columns]

# %%
import datetime 


data['Transaction Date'] = pd.to_datetime(data['Transaction Date']) 
data
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM       2011-01-01                 50
# 1          Mount Road ATM       2011-01-01                253
# 2             Airport ATM       2011-01-01                 98
# 3            KK Nagar ATM       2011-01-01                265
# 4      Christ College ATM       2011-01-01                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       2017-09-29                137
# 11585      Mount Road ATM       2017-09-29                 79
# 11586         Airport ATM       2017-09-29                117
# 11587        KK Nagar ATM       2017-09-29                 76
# 11588  Christ College ATM       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# 4                              25                            49
# ...                           ...                           ...
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                      123800                      41700
# 1                      767900                     270900
# 2                      503400                     347700
# 3                      945300                     532600
# 4                      287700                     148200
# ...                       ...                        ...
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                            82100  SATURDAY                 H           H
# 1                           497000  SATURDAY                 C           H
# 2                           155700  SATURDAY                 C           H
# 3                           412700  SATURDAY                 C           H
# 4                           139500  SATURDAY                 C           H
# ...                            ...       ...               ...         ...
# 11584                       322600    FRIDAY                 H           H
# 11585                       132600    FRIDAY                 H           H
# 11586                       133100    FRIDAY                 H           H
# 11587                       128800    FRIDAY                 H           H
# 11588                       336200    FRIDAY                 H           H
#
#       Holiday Sequence
# 0                  WHH
# 1                  WHH
# 2                  WHH
# 3                  WHH
# 4                  WHH
# ...                ...
# 11584              WHH
# 11585              WHH
# 11586              WHH
# 11587              WHH
# 11588              WHH
#
# [11589 rows x 12 columns]

# %%
data['Month'] = data['Transaction Date'].dt.month
data
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM       2011-01-01                 50
# 1          Mount Road ATM       2011-01-01                253
# 2             Airport ATM       2011-01-01                 98
# 3            KK Nagar ATM       2011-01-01                265
# 4      Christ College ATM       2011-01-01                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       2017-09-29                137
# 11585      Mount Road ATM       2017-09-29                 79
# 11586         Airport ATM       2017-09-29                117
# 11587        KK Nagar ATM       2017-09-29                 76
# 11588  Christ College ATM       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# 4                              25                            49
# ...                           ...                           ...
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                      123800                      41700
# 1                      767900                     270900
# 2                      503400                     347700
# 3                      945300                     532600
# 4                      287700                     148200
# ...                       ...                        ...
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                            82100  SATURDAY                 H           H
# 1                           497000  SATURDAY                 C           H
# 2                           155700  SATURDAY                 C           H
# 3                           412700  SATURDAY                 C           H
# 4                           139500  SATURDAY                 C           H
# ...                            ...       ...               ...         ...
# 11584                       322600    FRIDAY                 H           H
# 11585                       132600    FRIDAY                 H           H
# 11586                       133100    FRIDAY                 H           H
# 11587                       128800    FRIDAY                 H           H
# 11588                       336200    FRIDAY                 H           H
#
#       Holiday Sequence  Month
# 0                  WHH      1
# 1                  WHH      1
# 2                  WHH      1
# 3                  WHH      1
# 4                  WHH      1
# ...                ...    ...
# 11584              WHH      9
# 11585              WHH      9
# 11586              WHH      9
# 11587              WHH      9
# 11588              WHH      9
#
# [11589 rows x 13 columns]

# %%
data['Year'] = data['Transaction Date'].dt.year
data
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM       2011-01-01                 50
# 1          Mount Road ATM       2011-01-01                253
# 2             Airport ATM       2011-01-01                 98
# 3            KK Nagar ATM       2011-01-01                265
# 4      Christ College ATM       2011-01-01                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       2017-09-29                137
# 11585      Mount Road ATM       2017-09-29                 79
# 11586         Airport ATM       2017-09-29                117
# 11587        KK Nagar ATM       2017-09-29                 76
# 11588  Christ College ATM       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# 4                              25                            49
# ...                           ...                           ...
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                      123800                      41700
# 1                      767900                     270900
# 2                      503400                     347700
# 3                      945300                     532600
# 4                      287700                     148200
# ...                       ...                        ...
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                            82100  SATURDAY                 H           H
# 1                           497000  SATURDAY                 C           H
# 2                           155700  SATURDAY                 C           H
# 3                           412700  SATURDAY                 C           H
# 4                           139500  SATURDAY                 C           H
# ...                            ...       ...               ...         ...
# 11584                       322600    FRIDAY                 H           H
# 11585                       132600    FRIDAY                 H           H
# 11586                       133100    FRIDAY                 H           H
# 11587                       128800    FRIDAY                 H           H
# 11588                       336200    FRIDAY                 H           H
#
#       Holiday Sequence  Month  Year
# 0                  WHH      1  2011
# 1                  WHH      1  2011
# 2                  WHH      1  2011
# 3                  WHH      1  2011
# 4                  WHH      1  2011
# ...                ...    ...   ...
# 11584              WHH      9  2017
# 11585              WHH      9  2017
# 11586              WHH      9  2017
# 11587              WHH      9  2017
# 11588              WHH      9  2017
#
# [11589 rows x 14 columns]

# %%
data[data['Transaction Date']=='2016-01-26']
#26 january is represented by 'N' in the festival/ religion column
# Out:
#                 ATM Name Transaction Date  No Of Withdrawals  \
# 9095      Big Street ATM       2016-01-26                 46
# 9096        KK Nagar ATM       2016-01-26                248
# 9097  Christ College ATM       2016-01-26                 93
#
#       No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 9095                          17                            29
# 9096                         148                           100
# 9097                          50                            43
#
#       Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 9095                   74200                      43000
# 9096                 1207300                     836400
# 9097                  387200                     278200
#
#       Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 9095                        31200  TUESDAY                 N           H
# 9096                       370900  TUESDAY                 N           H
# 9097                       109000  TUESDAY                 N           H
#
#      Holiday Sequence  Month  Year
# 9095              WHW      1  2016
# 9096              WHW      1  2016
# 9097              WHW      1  2016

# %%
data[data['Transaction Date']=='2016-10-30']
#On this day, it was diwali and it falls under 'NH' category of festivals but the next 10 days also fall into the same category so the authenticity or correlation of this dataset with actual calendar is now doubtful.
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 10319      Big Street ATM       2016-10-30                103
# 10320      Mount Road ATM       2016-10-30                  9
# 10321         Airport ATM       2016-10-30                 40
# 10322        KK Nagar ATM       2016-10-30                 53
# 10323  Christ College ATM       2016-10-30                 69
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 10319                          13                            90
# 10320                           9                             0
# 10321                          30                            10
# 10322                          33                            20
# 10323                          34                            35
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 10319                  316500                      59400
# 10320                   23900                      23900
# 10321                  182800                     155900
# 10322                  278000                     186300
# 10323                  253300                     142100
#
#        Amount withdrawn Other Card Weekday Festival Religion Working Day  \
# 10319                       257100  SUNDAY                NH           H
# 10320                            0  SUNDAY                NH           H
# 10321                        26900  SUNDAY                NH           H
# 10322                        91700  SUNDAY                NH           H
# 10323                       111200  SUNDAY                NH           H
#
#       Holiday Sequence  Month  Year
# 10319              HHW     10  2016
# 10320              HHW     10  2016
# 10321              HHW     10  2016
# 10322              HHW     10  2016
# 10323              HHW     10  2016

# %%
Mountroad = data[data['ATM Name']=='Mount Road ATM'].drop(['ATM Name'],axis = 1)

# %%
Mountroad
# Out:
#       Transaction Date  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# 1           2011-01-01                253                          67
# 6           2011-02-01                194                          50
# 11          2011-03-01                246                         115
# 16          2011-04-01                246                          96
# 21          2011-05-01                211                         107
# ...                ...                ...                         ...
# 11565       2017-09-25                 91                          25
# 11570       2017-09-26                 59                          19
# 11575       2017-09-27                 63                          21
# 11580       2017-09-28                 87                          28
# 11585       2017-09-29                 79                          27
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# 1                               186                  767900
# 6                               144                  529300
# 11                              131                  897100
# 16                              150                  826000
# 21                              104                  754400
# ...                             ...                     ...
# 11565                            66                  447400
# 11570                            40                  153800
# 11575                            42                  167100
# 11580                            59                  317400
# 11585                            52                  305100
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card    Weekday  \
# 1                         270900                       497000   SATURDAY
# 6                         171700                       357600     SUNDAY
# 11                        462600                       434500     MONDAY
# 16                        374200                       451800    TUESDAY
# 21                        437800                       316600  WEDNESDAY
# ...                          ...                          ...        ...
# 11565                     257600                       189800     MONDAY
# 11570                      76200                        77600    TUESDAY
# 11575                      84700                        82400  WEDNESDAY
# 11580                     164900                       152500   THURSDAY
# 11585                     172500                       132600     FRIDAY
#
#       Festival Religion Working Day Holiday Sequence  Month  Year
# 1                     C           H              WHH      1  2011
# 6                    NH           H              HHW      2  2011
# 11                   NH           W              WWW      3  2011
# 16                   NH           W              WWW      4  2011
# 21                   NH           W              WWW      5  2011
# ...                 ...         ...              ...    ...   ...
# 11565                NH           W              HWW      9  2017
# 11570                NH           W              WWW      9  2017
# 11575                NH           W              WWW      9  2017
# 11580                NH           W              WWH      9  2017
# 11585                 H           H              WHH      9  2017
#
# [2256 rows x 13 columns]

# %%
Bigstreet = data[data['ATM Name']=='Big Street ATM'].drop(['ATM Name'],axis = 1)

# %%
Bigstreet
# Out:
#       Transaction Date  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# 0           2011-01-01                 50                          20
# 5           2011-02-01                 17                           5
# 10          2011-03-01                 24                          21
# 15          2011-04-01                 34                          12
# 20          2011-05-01                 30                          14
# ...                ...                ...                         ...
# 11564       2017-09-25                122                          41
# 11569       2017-09-26                131                          36
# 11574       2017-09-27                130                          40
# 11579       2017-09-28                137                          41
# 11584       2017-09-29                137                          34
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# 0                                30                  123800
# 5                                12                   52800
# 10                                3                   88100
# 15                               22                  101600
# 20                               16                   98000
# ...                             ...                     ...
# 11564                            81                  513800
# 11569                            95                  437400
# 11574                            90                  511200
# 11579                            96                  468600
# 11584                           103                  468800
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card    Weekday  \
# 0                          41700                        82100   SATURDAY
# 5                          20900                        31900     SUNDAY
# 10                         77100                        11000     MONDAY
# 15                         51200                        50400    TUESDAY
# 20                         52700                        45300  WEDNESDAY
# ...                          ...                          ...        ...
# 11564                     283000                       230800     MONDAY
# 11569                     162700                       274700    TUESDAY
# 11574                     215000                       296200  WEDNESDAY
# 11579                     221800                       246800   THURSDAY
# 11584                     146200                       322600     FRIDAY
#
#       Festival Religion Working Day Holiday Sequence  Month  Year
# 0                     H           H              WHH      1  2011
# 5                    NH           H              HHW      2  2011
# 10                   NH           W              WWW      3  2011
# 15                   NH           W              WWW      4  2011
# 20                   NH           W              WWW      5  2011
# ...                 ...         ...              ...    ...   ...
# 11564                NH           W              HWW      9  2017
# 11569                NH           W              WWW      9  2017
# 11574                NH           W              WWW      9  2017
# 11579                NH           W              WWH      9  2017
# 11584                 H           H              WHH      9  2017
#
# [2354 rows x 13 columns]

# %%
kknagar = data[data['ATM Name']=='KK Nagar ATM'].drop(['ATM Name'],axis = 1)

# %%
kknagar
# Out:
#       Transaction Date  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# 3           2011-01-01                265                         159
# 8           2011-02-01                260                         155
# 13          2011-03-01                309                         232
# 18          2011-04-01                225                         175
# 23          2011-05-01                255                         209
# ...                ...                ...                         ...
# 11567       2017-09-25                146                          92
# 11572       2017-09-26                 91                          67
# 11577       2017-09-27                117                          90
# 11582       2017-09-28                145                          97
# 11587       2017-09-29                 76                          48
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# 3                               106                  945300
# 8                               105                  809400
# 13                               77                 1333100
# 18                               50                  999400
# 23                               46                  959200
# ...                             ...                     ...
# 11567                            54                 1175200
# 11572                            24                  738200
# 11577                            27                  997800
# 11582                            48                 1154900
# 11587                            28                  408700
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card    Weekday  \
# 3                         532600                       412700   SATURDAY
# 8                         456200                       353200     SUNDAY
# 13                       1010600                       322500     MONDAY
# 18                        798800                       200600    TUESDAY
# 23                        806500                       152700  WEDNESDAY
# ...                          ...                          ...        ...
# 11567                     870900                       304300     MONDAY
# 11572                     614900                       123300    TUESDAY
# 11577                     872700                       125100  WEDNESDAY
# 11582                     905400                       249500   THURSDAY
# 11587                     279900                       128800     FRIDAY
#
#       Festival Religion Working Day Holiday Sequence  Month  Year
# 3                     C           H              WHH      1  2011
# 8                    NH           H              HHW      2  2011
# 13                   NH           W              WWW      3  2011
# 18                   NH           W              WWW      4  2011
# 23                   NH           W              WWW      5  2011
# ...                 ...         ...              ...    ...   ...
# 11567                NH           W              HWW      9  2017
# 11572                NH           W              WWW      9  2017
# 11577                NH           W              WWW      9  2017
# 11582                NH           W              WWH      9  2017
# 11587                 H           H              WHH      9  2017
#
# [2371 rows x 13 columns]

# %%
Airport = data[data['ATM Name']=='Airport ATM'].drop(['ATM Name'],axis = 1)

# %%
Airport
# Out:
#       Transaction Date  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# 2           2011-01-01                 98                          56
# 7           2011-02-01                 67                          53
# 12          2011-03-01                109                          90
# 17          2011-04-01                113                          80
# 22          2011-05-01                100                          70
# ...                ...                ...                         ...
# 11566       2017-09-25                 84                          51
# 11571       2017-09-26                 68                          52
# 11576       2017-09-27                100                          73
# 11581       2017-09-28                 68                          47
# 11586       2017-09-29                117                          77
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# 2                                42                  503400
# 7                                14                  268600
# 12                               19                  603900
# 17                               33                  541600
# 22                               30                  530000
# ...                             ...                     ...
# 11566                            33                  466700
# 11571                            16                  453900
# 11576                            27                  675500
# 11581                            21                  424700
# 11586                            40                  709900
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card    Weekday  \
# 2                         347700                       155700   SATURDAY
# 7                         213300                        55300     SUNDAY
# 12                        501800                       102100     MONDAY
# 17                        418400                       123200    TUESDAY
# 22                        424400                       105600  WEDNESDAY
# ...                          ...                          ...        ...
# 11566                     358600                       108100     MONDAY
# 11571                     415400                        38500    TUESDAY
# 11576                     590300                        85200  WEDNESDAY
# 11581                     299500                       125200   THURSDAY
# 11586                     576800                       133100     FRIDAY
#
#       Festival Religion Working Day Holiday Sequence  Month  Year
# 2                     C           H              WHH      1  2011
# 7                    NH           H              HHW      2  2011
# 12                   NH           W              WWW      3  2011
# 17                   NH           W              WWW      4  2011
# 22                   NH           W              WWW      5  2011
# ...                 ...         ...              ...    ...   ...
# 11566                NH           W              HWW      9  2017
# 11571                NH           W              WWW      9  2017
# 11576                NH           W              WWW      9  2017
# 11581                NH           W              WWH      9  2017
# 11586                 H           H              WHH      9  2017
#
# [2253 rows x 13 columns]

# %%
Christcollege = data[data['ATM Name']=='Christ College ATM'].drop(['ATM Name'],axis = 1)

# %%
Christcollege
# Out:
#       Transaction Date  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# 4           2011-01-01                 74                          25
# 9           2011-02-01                 80                          24
# 14          2011-03-01                108                          46
# 19          2011-04-01                143                          41
# 24          2011-05-01                 95                          41
# ...                ...                ...                         ...
# 11568       2017-09-25                174                          52
# 11573       2017-09-26                110                          34
# 11578       2017-09-27                149                          46
# 11583       2017-09-28                187                          76
# 11588       2017-09-29                143                          61
#
#        No Of Other Card Withdrawals  Total amount Withdrawn  \
# 4                                49                  287700
# 9                                56                  300000
# 14                               62                  522800
# 19                              102                  737400
# 24                               54                  387300
# ...                             ...                     ...
# 11568                           122                  755300
# 11573                            76                  325300
# 11578                           103                  722600
# 11583                           111                 1120300
# 11588                            82                  700400
#
#        Amount withdrawn XYZ Card  Amount withdrawn Other Card    Weekday  \
# 4                         148200                       139500   SATURDAY
# 9                          95600                       204400     SUNDAY
# 14                        210900                       311900     MONDAY
# 19                        238000                       499400    TUESDAY
# 24                        213600                       173700  WEDNESDAY
# ...                          ...                          ...        ...
# 11568                     310800                       444500     MONDAY
# 11573                      76000                       249300    TUESDAY
# 11578                     318100                       404500  WEDNESDAY
# 11583                     549100                       571200   THURSDAY
# 11588                     364200                       336200     FRIDAY
#
#       Festival Religion Working Day Holiday Sequence  Month  Year
# 4                     C           H              WHH      1  2011
# 9                    NH           H              HHW      2  2011
# 14                   NH           W              WWW      3  2011
# 19                   NH           W              WWW      4  2011
# 24                   NH           W              WWW      5  2011
# ...                 ...         ...              ...    ...   ...
# 11568                NH           W              HWW      9  2017
# 11573                NH           W              WWW      9  2017
# 11578                NH           W              WWW      9  2017
# 11583                NH           W              WWH      9  2017
# 11588                 H           H              WHH      9  2017
#
# [2355 rows x 13 columns]

# %%
data['ATM Name'].value_counts()
# Out:
# KK Nagar ATM          2371
# Christ College ATM    2355
# Big Street ATM        2354
# Mount Road ATM        2256
# Airport ATM           2253
# Name: ATM Name, dtype: int64

# %%
data['Working Day'].value_counts()
# Out:
# W    6621
# H    4968
# Name: Working Day, dtype: int64

# %%
data['Festival Religion'].value_counts()
#The definition of these symbols is unclear
# The various religions are NH, H, N, M, C
# I'm assuming NH = Not holy, H = Holy, could be anything
# Out:
# NH    10727
# H       367
# N       198
# M       178
# C       119
# Name: Festival Religion, dtype: int64

# %%
data['Weekday'].value_counts()
#tells us which days are busiest
# Out:
# SUNDAY       2686
# SATURDAY     1649
# TUESDAY      1502
# WEDNESDAY    1462
# MONDAY       1458
# THURSDAY     1420
# FRIDAY       1412
# Name: Weekday, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='ATM Name', data = data)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Weekday', y='Total amount Withdrawn', data=Bigstreet)

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Transaction Date', y='Total amount Withdrawn', data = data)
# Out:
# c:\users\vismit\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Year', y='Total amount Withdrawn', data = data)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Month', y='Total amount Withdrawn', data=data)

# %%
data['Holiday Sequence'].value_counts()
#It's important to keep the count of sequence equal while comparing data for the different sequences and we cannot say one sequence has more preference because more money was taken out in that pattern as it could also be because of more number of appearances of that sequence.
# Out:
# WWW    3621
# HHW    2763
# WHH    1678
# HWW    1447
# WWH    1408
# WHW     284
# HHH     253
# HWH     135
# Name: Holiday Sequence, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Holiday Sequence', y='Total amount Withdrawn', data=Bigstreet)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Working Day', y='Total amount Withdrawn', hue = "ATM Name",data=data)
#we can see all atms perform marginally better on working days compared to holidays except airport atm as holidays means more people flying across states and countries

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Festival Religion', y='Total amount Withdrawn',hue = "ATM Name", data=data)

# %%
sns.pairplot(data, hue = 'ATM Name')

# %%
plt.figure(figsize=(12,8))
df1 = data.corr()
sns.heatmap(df1, annot= True, cmap = 'viridis')
#Basically the data about cards is redundant for us as it has no major effect on total amount withdrawn on any day or at any time. it only shows frequency of certain card holding customers

# %%
plt.figure(figsize=(12,8))
cols = ['No Of XYZ Card Withdrawals', 'No Of Other Card Withdrawals', 'Amount withdrawn Other Card', 'Amount withdrawn XYZ Card']
df2 = df1.drop(cols , axis =1)
sns.heatmap(df2)

# %%
#All following scatter plots add no knowledge to the research other than predicatable graph that we already knew

# %%
sns.scatterplot(x= 'No Of Withdrawals', y= 'Total amount Withdrawn', data = Bigstreet)

# %%
sns.scatterplot(x= 'No Of Withdrawals', y= 'Total amount Withdrawn', data = Airport)

# %%
sns.scatterplot(x= 'No Of Withdrawals', y= 'Total amount Withdrawn', data = Christcollege)

# %%
sns.scatterplot(x= 'No Of Withdrawals', y= 'Total amount Withdrawn', data = kknagar)

# %%
sns.scatterplot(x= 'No Of Withdrawals', y= 'Total amount Withdrawn', data = Mountroad)

# %%
sns.jointplot(x='No Of Withdrawals', y='Total amount Withdrawn',kind= "kde", data = data)
#linearly increases for obvious reason that more amount will be withdrawn as the number of withdrawals increases
